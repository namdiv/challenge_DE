# %% [markdown]
# ## ​2. Los top 10 emojis más usados con su respectivo conteo

# %% [markdown]
# ### Estructura del notebook:
# 1. Explicación detallada del código
# 2. Revisión de tiempos de ejecución y memoria de q1_time.py y q1_memory.py

# %%
import pandas as pd
import emoji
from collections import Counter

# %%
def get_most_common_elements(elements: list, n:int =10):
    """Extrae los n elementos más comunes de una lista junto con su respectivo conteo.

    Args:
        elements (list): lista de elementos que deseamos contar.
        n (int, optional): cantidad de elementos que deseamos obtener. Devuelve los 10 más comunes por defecto.

    Returns:
        list: lista de tuplas con los elementos más comunes y su conteo. Ejemplo [(elem1, 15), (elem2, 12), (elem3, 7),...]
    """
    _counter = Counter(elements)
    most_common_elements = _counter.most_common(n)
    return most_common_elements

def extract_emojis(text: str):
    """Extrae los emojis contenido en un string. Los emojis son identificados por la librería emoji.

    Args:
        text (str): texto que contiene los emojis que queremos extraer.

    Returns:
        list: lista con los emojis extraídos. Cada elemento corresponde a un emoji.
    """
    return [e.get('emoji') for e in emoji.emoji_list(text)]

# %% [markdown]
# ### Lectura de los datos. La estructura de los datos son un objeto JSON por cada fila.

# %%
import jsonlines

def read_json_lines(file_path, cols):
    data = []
    with jsonlines.open(file_path) as reader:
        for item in reader:
            item = {key: item[key] for key in cols if key in item}
            data.append(item)
    return pd.DataFrame(data)

# %%
file_path = "../farmers-protest-tweets-2021-2-4.json"
df = pd.read_json(path_or_buf=file_path, lines=True)

# %% [markdown]
# ### Aplicamos la función extract_emojis en cada registro de la columna content.

# %%
emojis = df['content'].apply(extract_emojis)
emojis
# Out:
# 0                   []
# 1            [🚜, 🌾, 💪]
# 2         [🤫, 🤫, 🤔, 🤔]
# 3                   []
# 4                   []
#               ...
# 117402              []
# 117403              []
# 117404              []
# 117405              []
# 117406             [💪]
# Name: content, Length: 117407, dtype: object

# %% [markdown]
# ### La lista "emojis" tiene listas como elementos (es una lista de listas).
# ### Con este bucle concatenamos todas las listas en una sola.

# %%
emojis_list = []
for i in emojis:
    emojis_list += i
print(emojis_list)
# Out:
# ['🚜', '🌾', '💪', '🤫', '🤫', '🤔', '🤔', '🙄', '🙄', '🇮🇳', '👇', '👇', '🙏🏽', '‼', '👍', '👍', '🙏🏻', '👇🏽', '🙌', '🙌', '💜', '🤣', '🧑\u200d🌾', '👩\u200d🌾', '🌱', '🕊', '🌍', '🤣', '🤣', '🤣', '🤔', '😱', '🧑\u200d🌾', '👩\u200d🌾', '🌱', '🕊', '🌍', '🙏🏻', '👇🏾', '👇🏾', '‼', '✨', '💫', '🌈', '🌼', '❣️', '🔰', '😂', '😂', '😂', '✍🏻', '💪', '💪', '💪', '☘️', '💚', '🇮🇳', '🇵🇰', '🇮🇳', '🙏🏻', '😛', '♨️', '♨️', '✊', '💔', '✊🏾', '✊🏾', '🚜', '🌾', '👍🏻', '💪🏻', '👇🏻', '👇🏻', '👇🏻', '👇🏻', '👇🏻', '👇🏻', '👇🏻', '👇🏻', '👇🏻', '👇🏻', '👇🏻', '🤨', '🤨', '✊🏽', '🥳', '🔥', '🚜', '🌾', '😅', '😅', '😅', '🤣', '🤣', '🤣', '😂', '😂', '😂', '👇', '👇', '👏🏽', '👏🏽', '🙏', '👍', '👍', '👏', '😢', '📢', '👇🏼', '🥺', '🥺', '💔', '🙏🏽', '✊', '✊', '👇🏽', '😛', '😛', '😛', '☀️', '🌄', '🤔', '❤️', '✊', '🤣', '🤣', '🤣', '🤣', '🤔', '🙌', '🙌', '👏', '👏', '👏', '🙏', '💚', '💚', '💚', '💔', '💔', '💔', '😡', '😡', '😡', '🤣', '🤣', '🤣', '🤣', '🤣', '✊', '😜', '🤣', '😂', '🤣', '🌾', '🌾', '💪🏻', '💪🏻', '😎', '😎', '🙏', '🙏', '🙏', '🙏', '😂', '😂', '😂', '🙏', '🙏', '😊', '😊', '😂', '😂', '💪🏻', '💪🏻', '💪🏻', '😂', '😂', '😂', '😂', '😂', '💪🏻', '💪🏻', '🤯', '🤯', '💪🏻', '🙏', '😂', '😂', '😂', '😂', '😂', '😒', '😊', '💪', '💯', '💔', '📸', '🙏', '🙏', '😂', '😂', '😂', '😂', '😂', '🙄', '🙄', '🙄', '🙄', '🙏', '🙏', '🙏', '💪🏻', '💪🏻', '💪🏻', '😂', '😂', '😂', '😂', '😂', '😂', '😂', '😂', '💯', '💪', '😒', '👇', '👇', '👇', '👇', '🤦\u200d♀️', '😂', '⤵️', '📷', '🙏🏻', '👇', '👇', '👇', '👇', '🤦🏼\u200d♂️', '🤦🏼\u200d♂️', '🤦🏼\u200d♂️', '🙏', '🙏', '🙏', '🙏', '🙏', '🙏', '🙏', '🙏', '🙏', '👍🏼', '👍🏼', '❤️', '😂', '🤣', '🤣', '💪🏽', '🇮🇳', '🇮🇳', '🇮🇳', '😡', '😡', '💕', '🇮🇳', '🇮🇳', '🇮🇳', '😡', '😡', '💪🏽', '🙏🏻', '🙏🏻', '🚜', '🌾', '🙏🏻', '🙏🏻', '🚜', '🌾', '🙏🏻', '🙏🏻', '🚜', '🌾', '🙏', '🙏', '🙏', '🙏', '🙏', '👳', '👳', '👳', '👳', '🙏🏻', '🙏🏻', '🚜', '🌾', '😂', '😂', '😛', '😛', '🤔', '🤔', '❤️', '😞', '✊', '✊', '👍', '👇', '👇', '👇', '👇', '😁', '😂', '😂', '❤', '⛽', '🤝', '🚜', '🌾', '❗', '🙏', '🙏', '🙏', '🤝', '💪', '💪', '💪', '😶', '💚', '✊🏼', '🌾', '🚜', '4️⃣', '🚜', '🚜', '🚜', '🔥', '😍', '😂', '🤣', '🤣', '😍', '😂', '🌾', '🦁', '🦁', '🔥', '🔥', '👇🏾', '👇🏾', '❤️', '🌍', '🌏', '🌎', '🌳', '🌱', '🌿', '💮', '🏵️', '🌺', '🌻', '🌞', '🦋', '🌾', '♥️', '😂', '😂', '😂', '👌', '👌', '👌', '👌', '👏', '😃', '🤦\u200d♂️', '🤦\u200d♂️', '🤣', '🤣', '🤣', '👞', '👞', '✊🏽', '💪', '🙄', '😆', '😆', '🙌🏻', '🌾', '💪', '🙏🏻', '🙏', '✌️', '✌️', '✌️', '✌️', '✌️', '🇦🇺', '🇦🇺', '🇦🇺', '🙏', '🙏', '🙏', '🙏', '🙏🏻', '🙏🏻', '😡', '😎', '😎', '😂', '🙏', '❤️', '🙏', '🔥', '💪', '☑️', '😀', '💪', '👏', '🇮🇳', '☑️', '🇮🇳', '😂', '😂', '👍', '👍', '🇺🇸', '🇮🇳', '😂', '🤔', '🙏', '🙏', '🙏', '❤️', '🙏', '✊🏾', '🙏', '❤️', '🙏', '🙏', '❤️', '🙏', '🇮🇳', '🙏', '🙏', '😻', '😁', '😽', '😂', '😂', '😂', '😛', '😻', '😁', '😽', '😂', '😂', '😂', '😛', '🤦\u200d♀️', '🙏', '📸', '🤓', '✊', '😂', '🤣', '🤣', '👇', '🌾', '🌾', '🙈', '🤣', '☀️', '🌾', '🍞', '💪🏻', '🙏', '☀️', '🌾', '🍞', '💪🏻', '👳', '❓', '❓', '☀️', '🌾', '🍞', '💪🏻', '☀️', '🌾', '🍞', '💪🏻', '🙏', '🙏', '💪', '💪', '☀️', '🌾', '🍞', '💪🏻', '🙏', '🙏', '💪', '💪', '🙏', '🙏', '💪', '💪', '🥗', '🍛', '😂', '😀', '🤣', '🤣', '☀️', '🌾', '🍞', '💪🏻', '☀️', '🌾', '🍞', '💪🏻', '🤣', '🙏', '☀️', '🌾', '🍞', '💪🏻', '☀️', '🌾', '🍞', '💪🏻', '🤣', '☀️', '🌾', '🍞', '💪🏻', '🤣', '😂', '😂', '😂', '✊', '👍', '🙏', '👏', '😂', '😀', '✊', '🤣', '🤣', '🌾', '🍞', '🌾', '🍞', '🌾', '🍞', '👍', '🌾', '🍞', '🌾', '🍞', '🌾', '🍞', '🌾', '🍞', '🌾', '🍞', '✊🏻', '💪🏻', '🌾', '🍞', '✊🏻', '💪🏻', '✊🏻', '💪🏻', '✊🏻', '💪🏻', '🙏', '✊🏻', '💪🏻', '🙏', '👍', '✊🏻', '💪🏻', '🙏', '👍', '🙏🏽', '🙏', '👍', '🚜', '🚜', '🌾', '🌾', '🚜', '🚜', '🙏', '🚜', '🚜', '🌾', '🌾', '🚜', '🚜', '🦹', '🌾', '👊', '💪', '🕺', '😜', '🇮🇳', '🌾', '🚜', '🇮🇳', '🌾', '🚜', '🙏', '👍', '🇮🇳', '🌾', '🚜', '👌', '👌', '🇮🇳', '🌾', '🚜', '🇮🇳', '🌾', '🚜', '🇮🇳', '🌾', '🚜', '🇮🇳', '🌾', '🚜', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🙏', '🙏', '🙏', '🙏', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🙏', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾', '🌾 ...

# %% [markdown]
# ### Retornamos la salida de get_most_common_elements.

# %%
get_most_common_elements(emojis_list)
# Out:
# [('🙏', 5049),
#  ('😂', 3072),
#  ('🚜', 2972),
#  ('🌾', 2182),
#  ('🇮🇳', 2086),
#  ('🤣', 1668),
#  ('✊', 1651),
#  ('❤️', 1382),
#  ('🙏🏻', 1317),
#  ('💚', 1040)]

# %% [markdown]
# ----
# ## Tiempo de ejecución de q2_time

# %%
import cProfile

def q2_time(file_path: str):
    # Lectura de los datos. La estructura de los datos son un objeto JSON por cada fila.
    df = read_json_lines(file_path, cols=['content'])

    # Aplicamos la función extract_emojis en cada registro de la columna content.
    # La columna content representa el contenido (texto) del tweet. Por lo tanto, 
    # es la que nos interesa y en donde estarán los emojis.
    emojis = df['content'].apply(extract_emojis)

    # La lista "emojis" tiene listas como elementos (es una lista de listas).
    # Con este bucle concatenamos todas las listas en una sola.
    emojis_list = []
    for i in emojis:
        emojis_list += i

    # Retornamos la salida de get_most_common_elements.
    return get_most_common_elements(emojis_list)

cProfile.run("q2_time('../farmers-protest-tweets-2021-2-4.json')")
# Out:
#          88405093 function calls (88405074 primitive calls) in 18.469 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.131    0.131    2.190    2.190 178636768.py:3(read_json_lines)
#    117407    0.017    0.000    0.017    0.000 178636768.py:7(<dictcomp>)
#         1    0.000    0.000    0.004    0.004 262797740.py:1(get_most_common_elements)
#    117407    0.047    0.000   16.220    0.000 262797740.py:15(extract_emojis)
#    117407    0.015    0.000    0.018    0.000 262797740.py:24(<listcomp>)
#         1    0.015    0.015   18.460   18.460 3476377018.py:3(q2_time)
#         1    0.000    0.000    0.000    0.000 <attrs generated init jsonlines.jsonlines.Reader>:1(__init__)
#         8    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#       4/1    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:309(__init__)
#     49772    0.019    0.000    0.057    0.000 <frozen codecs>:319(decode)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:94(__new__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:100(acquire)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1026(__enter__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1030(__exit__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1054(_find_spec)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:1120(_find_and_load_unlocked)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:1165(_find_and_load)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:125(release)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:165(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:169(__enter__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:198(cb)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:233(_call_with_frames_removed)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:244(_verbose_message)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:357(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:392(cached)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:405(parent)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:413(has_location)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:48(_new_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:493(_init_module_attrs)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:566(module_from_spec)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:666(_load_unlocked)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:71(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:748(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:920(find_spec)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1007(get_code)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1097(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1122(get_filename)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1127(get_data)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1146(path_stats)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:126(_path_join)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:128(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:134(<genexpr>)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1421(_path_importer_cache)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1464(_get_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1496(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:159(_path_isfile)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1599(_get_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1604(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:180(_path_isabs)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:437(cache_from_source)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:567(_get_cached)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:599(_check_name_wrapper)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:642(_classify_pyc)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:67(_relax_case)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:675(_validate_timestamp_pyc)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:727(_compile_bytecode)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:778(spec_from_file_location)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:84(_unpack_uint32)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:931(create_module)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:934(exec_module)
#  17023302    1.843    0.000    3.547    0.000 <string>:1(<lambda>)
#         1    0.009    0.009   18.469   18.469 <string>:1(<module>)
#    117407    0.058    0.000    1.478    0.000 __init__.py:299(loads)
#         4    0.000    0.000    0.000    0.000 __init__.py:33(using_copy_on_write)
#         1    0.000    0.000    0.000    0.000 __init__.py:43(normalize_encoding)
#         3    0.000    0.000    0.000    0.000 __init__.py:43(using_pyarrow_string_dtype)
#         1    0.000    0.000    0.004    0.004 __init__.py:587(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:610(most_common)
#         1    0.000    0.000    0.004    0.004 __init__.py:660(update)
#         1    0.000    0.000    0.002    0.002 __init__.py:71(search_function)
#         1    0.000    0.000    0.000    0.000 __init__.py:89(find_spec)
#         1    0.000    0.000    0.000    0.000 _asarray.py:108(<setcomp>)
#         1    0.000    0.000    0.000    0.000 _asarray.py:27(require)
#         1    0.000    0.000   16.251   16.251 algorithms.py:1738(map_array)
#         1    0.000    0.000    0.000    0.000 api.py:379(default_index)
#         1    0.000    0.000    0.000    0.000 apply.py:111(__init__)
#         1    0.000    0.000    0.000    0.000 apply.py:1157(__init__)
#         1    0.000    0.000   16.252   16.252 apply.py:1189(apply)
#         1    0.000    0.000   16.252   16.252 apply.py:1262(apply_standard)
#         1    0.000    0.000    0.000    0.000 base.py:2292(is_unique)
#         1    0.000    0.000    0.000    0.000 base.py:3762(get_loc)
#         1    0.000    0.000    0.000    0.000 base.py:458(_engine_type)
#         1    0.000    0.000    0.000    0.000 base.py:477(__new__)
#         6    0.000    0.000    0.000    0.000 base.py:5126(_values)
#         1    0.000    0.000    0.000    0.000 base.py:5152(_get_engine_target)
#         1    0.000    0.000    0.000    0.000 base.py:5299(__contains__)
#         2    0.000    0.000    0.000    0.000 base.py:5349(__getitem__)
#         1    0.000    0.000    0.000    0.000 base.py:573(_ensure_array)
#         1    0.000    0.000    0.000    0.000 base.py:591(_dtype_to_subclass)
#         1    0.000    0.000    0.000    0.000 base.py:61(__len__)
#         1    0.000    0.000    0.000    0.000 base.py:648(_simple_new)
#         1    0.000    0.000    0.000    0.000 base.py:6611(_maybe_cast_indexer)
#         1    0.000    0.000    0.000    0.000 base.py:69(shape)
#         3    0.000    0.000    0.000    0.000 base.py:71(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:73(_validate_set_axis)
#         6    0.000    0.000    0.000    0.000 base.py:7512(ensure_index)
#         2    0.000    0.000    0.000    0.000 base.py:7607(maybe_extract_name)
#         2    0.000    0.000    0.000    0.000 base.py:830(_reset_identity)
#         2    0.000    0.000    0.000    0.000 base.py:836(__iter__)
#         1    0.000    0.000    0.000    0.000 base.py:841(_engine)
#         1    0.000    0.000   16.251   16.251 base.py:891(_map_values)
#         4    0.000    0.000    0.000    0.000 base.py:908(__len__)
#         1    0.000    0.000    0.000    0.000 base.py:973(dtype)
#         1    0.000    0.000    0.000    0.000 blocks.py:1007(iget)
#         1    0.000    0.000    0.000    0.000 blocks.py:2317(maybe_coerce_values)
#         2    0.000    0.000    0.000    0.000 blocks.py:2346(get_block_type)
#         1    0.000    0.000    0.000    0.000 blocks.py:2388(new_block)
#         1    0.000    0.000    0.000    0.000 blocks.py:583(dtype)
#         4    0.000    0.000    0.001    0.000 cast.py:1147(maybe_infer_to_datetimelike)
#         1    0.000    0.000    0.000    0.000 cast.py:119(maybe_convert_platform)
#         1    0.000    0.000    0.000    0.000 cast.py:1544(construct_1d_object_array_from_listlike)
#         1    0.000    0.000    0.000    0.000 common.py:1025(needs_i8_conversion)
#         1    0.000    0.000    0.000    0.000 common.py:1255(is_1d_only_ea_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:1322(is_ea_or_datetimelike_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:149(cast_scalar_indexer)
#         1    0.000    0.000    0.000    0.000 common.py:1562(validate_all_hashable)
#         2    0.000    0.000    0.000    0.000 common.py:1581(<genexpr>)
#         1    0.000    0.000    0.000    0.000 common.py:367(apply_if_callable)
#         2    0.000    0.000    0.000    0.000 common.py:556(require_length_match)
#         2    0.000    0.000    0.000    0.000 config.py:127(_get_single_key)
#         2    0.000    0.000    0.000    0.000 config.py:145(_get_option)
#         2    0.000    0.000    0.000    0.000 config.py:271(__call__)
#         2    0.000    0.000    0.000    0.000 config.py:615(_select_options)
#         2    0.000    0.000    0.000    0.000 config.py:633(_get_root)
#         4    0.000    0.000    0.000    0.000 config.py:647(_get_deprecated_option)
#         2    0.000    0.000    0.000    0.000 config.py:674(_translate_key)
#         2    0.000    0.000    0.000    0.000 config.py:686(_warn_if_deprecated)
#         1    0.000    0.000    0.000    0.000 construction.py:1006(convert_object_array)
#         1    0.000    0.000    0.000    0.000 construction.py:1028(convert)
#         1    0.000    0.000    0.000    0.000 construction.py:1068(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:196(mgr_to_mgr)
#         3    0.000    0.000    0.000    0.000 construction.py:419(extract_array)
#         2    0.000    0.000    0.000    0.000 construction.py:484(ensure_wrapped_if_datetimelike)
#         1    0.000    0.000    0.049    0.049 construction.py:506(nested_data_to_arrays)
#         3    0.000    0.000    0.001    0.000 construction.py:518(sanitize_array)
#         1    0.000    0.000    0.000    0.000 construction.py:532(treat_as_nested)
#         1    0.000    0.000    0.000    0.000 construction.py:596(_homogenize)
#         1    0.000    0.000    0.000    0.000 construction.py:675(_sanitize_non_ordered)
#         3    0.000    0.000    0.000    0.000 construction.py:683(_sanitize_ndim)
#         3    0.000    0.000    0.000    0.000 construction.py:722(_sanitize_str_dtypes)
#         3    0.000    0.000    0.000    0.000 construction.py:742(_maybe_repeat)
#         1    0.000    0.000    0.049    0.049 construction.py:793(to_arrays)
#         1    0.000    0.000    0.049    0.049 construction.py:891(_list_of_dict_to_arrays)
#    117408    0.023    0.000    0.026    0.000 construction.py:915(<genexpr>)
#         2    0.000    0.000    0.000    0.000 construction.py:916(<genexpr>)
#         1    0.009    0.009    0.009    0.009 construction.py:922(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:928(_finalize_columns_and_data)
#         1    0.000    0.000    0.000    0.000 construction.py:950(_validate_or_indexify_columns)
#         1    0.000    0.000    0.001    0.001 construction.py:96(arrays_to_mgr)
#    117407    0.038    0.000   16.156    0.000 core.py:282(emoji_list)
#    117407    2.928    0.000   16.117    0.000 core.py:289(<listcomp>)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:1256(is_dataclass)
#    117407    0.093    0.000    1.404    0.000 decoder.py:332(decode)
#    117407    1.255    0.000    1.255    0.000 decoder.py:343(raw_decode)
#         3    0.000    0.000    0.000    0.000 flags.py:53(__init__)
#         2    0.000    0.000    0.000    0.000 flags.py:57(allows_duplicate_labels)
#         2    0.000    0.000    0.000    0.000 flags.py:89(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 frame.py:3776(_ixs)
#         1    0.000    0.000    0.000    0.000 frame.py:3853(__getitem__)
#         1    0.000    0.000    0.000    0.000 frame.py:4384(_box_col_values)
#         1    0.000    0.000    0.000    0.000 frame.py:4402(_get_item_cache)
#         1    0.000    0.000    0.000    0.000 frame.py:651(_sliced_from_mgr)
#         1    0.000    0.000    0.000    0.000 frame.py:654(_constructor_sliced_from_mgr)
#         1    0.000    0.000    0.050    0.050 frame.py:665(__init__)
#         3    0.000    0.000    0.000    0.000 generic.py:274(__init__)
#         1    0.000    0.000    0.000    0.000 generic.py:335(_from_mgr)
#         2    0.000    0.000    0.000    0.000 generic.py:358(attrs)
#        12    0.000    0.000    0.000    0.000 generic.py:37(_check)
#         4    0.000    0.000    0.000    0.000 generic.py:393(flags)
#        12    0.000    0.000    0.000    0.000 generic.py:42(_instancecheck)
#         2    0.000    0.000    0.000    0.000 generic.py:6147(__finalize__)
#         1    0.000    0.000    0.000    0.000 generic.py:6189(__getattr__)
#         5    0.000    0.000    0.000    0.000 generic.py:6206(__setattr__)
#         1    0.000    0.000    0.000    0.000 generic.py:760(_set_axis)
#         1    0.000    0.000    0.000    0.000 heapq.py:523(nlargest)
#         1    0.000    0.000    0.000    0.000 heapq.py:565(<listcomp>)
#         1    0.000    0.000    0.000    0.000 heapq.py:579(<listcomp>)
#         1    0.000    0.000    0.000    0.000 indexing.py:2678(check_dict_or_set_indexers)
#         1    0.000    0.000    0.000    0.000 inference.py:273(is_dict_like)
#         2    0.000    0.000    0.000    0.000 inference.py:300(<genexpr>)
#         1    0.000    0.000    0.000    0.000 inference.py:306(is_named_tuple)
#         4    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#         1    0.000    0.000    0.000    0.000 inference.py:404(is_dataclass)
#         1    0.000    0.000    0.000    0.000 jsonlines.py:153(close)
#         1    0.000    0.000    0.000    0.000 jsonlines.py:175(__enter__)
#         1    0.000    0.000    0.000    0.000 jsonlines.py:178(__exit__)
#         1    0.000    0.000    0.000    0.000 jsonlines.py:214(__attrs_post_init__)
#    117408    0.088    0.000    1.957    0.000 jsonlines.py:278(read)
#    117408    0.027    0.000    1.984    0.000 jsonlines.py:410(iter)
#         1    0.000    0.000    0.000    0.000 jsonlines.py:443(__iter__)
#         1    0.000    0.000    0.002    0.002 jsonlines.py:604(open)
#         1    0.000    0.000    0.000    0.000 jsonlines.py:651(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 managers.py:169(blknos)
#         1    0.000    0.000    0.000    0.000 managers.py:1726(is_consolidated)
#         1    0.000    0.000    0.000    0.000 managers.py:1734(_consolidate_check)
#         1    0.000    0.000    0.000    0.000 managers.py:1744(_consolidate_inplace)
#         2    0.000    0.000    0.000    0.000 managers.py:1799(__init__)
#         1    0.000    0.000    0.000    0.000 managers.py:1825(from_array)
#         1    0.000    0.000    0.000    0.000 managers.py:185(blklocs)
#         2    0.000    0.000    0.000    0.000 managers.py:1902(_block)
#         1    0.000    0.000    0.000    0.000 managers.py:1949(dtype)
#         4    0.000    0.000    0.000    0.000 managers.py:1960(internal_values)
#         1    0.000    0.000    0.001    0.001 managers.py:2068(create_block_manager_from_column_arrays)
#         1    0.000    0.000    0.000    0.000 managers.py:2124(_grouping_func)
#         1    0.000    0.000    0.001    0.001 managers.py:2137(_form_blocks)
#         1    0.001    0.001    0.001    0.001 managers.py:2194(_stack_arrays)
#         1    0.000    0.000    0.000    0.000 managers.py:225(set_axis)
#         1    0.000    0.000    0.000    0.000 managers.py:235(items)
#         1    0.000    0.000    0.000    0.000 managers.py:896(__init__)
#         1    0.000    0.000    0.000    0.000 managers.py:991(iget)
#         7    0.000    0.000    0.000    0.000 multiarray.py:1080(copyto)
#         7    0.000    0.000    0.000    0.000 numeric.py:274(full)
#         1    0.000    0.000    0.000    0.000 range.py:198(_simple_new)
#         7    0.000    0.000    0.000    0.000 range.py:963(__len__)
#         1    0.000    0.000    0.000    0.000 series.py:1372(_set_as_cached)
#         1    0.000    0.000    0.000    0.000 series.py:1381(_clear_item_cache)
#         1    0.000    0.000    0.001    0.001 series.py:371(__init__)
#         1    0.000    0.000   16.252   16.252 series.py:4625(apply)
#         1    0.000    0.000    0.000    0.000 series.py:577(_constructor)
#         1    0.000    0.000    0.000    0.000 series.py:626(dtype)
#         1    0.000    0.000    0.000    0.000 series.py:653(name)
#         1    0.000    0.000    0.000    0.000 series.py:703(name)
#         4    0.000    0.000    0.000    0.000 series.py:750(_values)
#         1    0.000    0.000    0.000    0.000 series.py:821(__len__)
#  17140706    8.310    0.000   12.456    0.000 tokenizer.py:158(tokenize)
#     42922    0.007    0.000    0.007    0.000 tokenizer.py:29(__init__)
#    117407    0.008    0.000    0.008    0.000 tokenizer.py:301(get_search_tree)
#         2    0.000    0.000    0.000    0.000 typing.py:1371(__hash__)
#         8    0.000    0.000    0.000    0.000 typing.py:2256(cast)
#         3    0.000    0.000    0.000    0.000 typing.py:352(inner)
#         1    0.000    0.000    0.000    0.000 utf_8_sig.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 utf_8_sig.py:121(getregentry)
#         1    0.000    0.000    0.000    0.000 utf_8_sig.py:26(IncrementalEncoder)
#         1    0.000    0.000    0.000    0.000 utf_8_sig.py:49(IncrementalDecoder)
#         1    0.000    0.000    0.000    0.000 utf_8_sig.py:50(__init__)
#     49772    0.012    0.000    0.039    0.000 utf_8_sig.py:54(_buffer_decode)
#         1    0.000    0.000    0.000    0.000 utf_8_sig.py:85(StreamWriter)
#         1    0.000    0.000    0.000    0.000 utf_8_sig.py:97(StreamReader)
#  17023306    1.704    0.000    1.704    0.000 {built-in method __new__ of type object at 0x105effd60}
#         8    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#       4/1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#     49772    0.027    0.000    0.027    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.004    0.004    0.004    0.004 {built-in method _collections._count_elements}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heapify}
#         8    0.000    0.000    0.000    0.000 {built-in method _heapq.heapreplace}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#         6    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.find_frozen}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#         6    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#         1    0.000    0.000    0.002    0.002 {built-in method builtins.__import__}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       2/1    0.000    0.000   18.469   18.469 {built-in method builtins.exec}
#        27    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#  17258236    0.747    0.000    0.747    0.000 {built-in method builtins.isinstance}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 234876/234864    0.014    0.000    0.014    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#    117408    0.315    0.000    0.372    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         3    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open_code}
#         1    0.000    0.000    0.002    0.002 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 {built-in method marshal.loads}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         7    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         9    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         3    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         3    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#         1    0.000    0.000    0.000    0.000 {method 'add_index_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#  17140725    0.581    0.000    0.581    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    234814    0.012    0.000    0.012    0.000 {method 'end' of 're.Match' objects}
#         1    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#     42930    0.002    0.000    0.002    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         9    0.000    0.000    0.000    0.000 {method 'isalnum' of 'str' objects}
#         7    0.000    0.000    0.000    0.000 {method 'isascii' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         9    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#    117407    0.004    0.000    0.004    0.000 {method 'keys' of 'dict' objects}
#    234814    0.039    0.000    0.039    0.000 {method 'match' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         1    0.001    0.001    0.001    0.001 {method 'read' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#        14    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#    234816    0.022    0.000    0.022    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.006    0.006    0.006    0.006 {pandas._libs.lib.dicts_to_array}
#         1    0.007    0.007    0.033    0.033 {pandas._libs.lib.fast_unique_multiple_list_gen}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#         8    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_np_dtype}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#         1    0.031    0.031   16.251   16.251 {pandas._libs.lib.map_infer}
#         6    0.001    0.000    0.001    0.000 {pandas._libs.lib.maybe_convert_objects}

# %% [markdown]
# ## Consumo de memoria de q2_time

# %% [markdown]
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     70    102.9 MiB    102.9 MiB           1   @profile
#     71                                         def q2_time(file_path: str):
#     72                                             # Lectura de los datos. La estructura de los datos son un objeto JSON por cada fila.
#     73    171.2 MiB     68.3 MiB           1       df = read_json_lines(file_path, cols=['content'])
#     74
#     75                                             # Aplicamos la función extract_emojis en cada registro de la columna content.
#     76                                             # La columna content representa el contenido (texto) del tweet. Por lo tanto,
#     77                                             # es la que nos interesa y en donde estarán los emojis.
#     78    176.0 MiB      4.8 MiB           1       emojis = df['content'].apply(extract_emojis)
#     79
#     80                                             # La lista "emojis" tiene listas como elementos (es una lista de listas).
#     81                                             # Con este bucle concatenamos todas las listas en una sola.
#     82    176.0 MiB      0.0 MiB           1       emojis_list = []
#     83    176.4 MiB      0.0 MiB      117408       for i in emojis:
#     84    176.4 MiB      0.3 MiB      117407           emojis_list += i
#     85
#     86                                             # Retornamos la salida de get_most_common_elements.
#     87    176.4 MiB      0.0 MiB           1       return get_most_common_elements(emojis_list)

# %% [markdown]
# ## Tiempo de ejecución de q2_memory

# %%
def q2_memory(file_path: str):
    # Este código es el mismo que q2_time.py con la diferencia que leemos los datos en particiones 
    # para ahorrar memoria.
    # Para realizar esto, utilizamos el parámetro chunksize.
    # Por lo tanto, es necesario hacer un bucle "for" y sacrificar procesamiento.
     
    emoji_lists = []
    for chunk in pd.read_json(path_or_buf=file_path, lines=True, chunksize=50):
        emojis = chunk['content'].apply(extract_emojis)
        emoji_lists.extend(emojis) #extend nos permite concatenar listas y almacenar los resultados de cada partición

    # La lista "emojis_list" tiene listas como elementos (es una lista de listas).
    # Con este bucle concatenamos todas las listas en una sola.
    all_emojis = []
    for i in emoji_lists:
        all_emojis += i

    # Retornamos la salida de get_most_common_elements.
    return get_most_common_elements(all_emojis)

cProfile.run("q2_memory('../farmers-protest-tweets-2021-2-4.json')")
# Out:
#          124097871 function calls (123348540 primitive calls) in 32.517 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.004    0.004 262797740.py:1(get_most_common_elements)
#    117407    0.051    0.000   15.912    0.000 262797740.py:15(extract_emojis)
#    117407    0.017    0.000    0.020    0.000 262797740.py:24(<listcomp>)
#         1    0.301    0.301   32.512   32.512 3301829030.py:1(q2_memory)
#    263098    0.038    0.000    0.071    0.000 <frozen abc>:117(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:309(__init__)
#     49773    0.017    0.000    0.048    0.000 <frozen codecs>:319(decode)
#         1    0.000    0.000    0.000    0.000 <frozen genericpath>:16(exists)
#     18792    0.010    0.000    0.012    0.000 <frozen importlib._bootstrap>:1207(_handle_fromlist)
#         5    0.000    0.000    0.000    0.000 <frozen posixpath>:229(expanduser)
#  17023302    1.872    0.000    3.032    0.000 <string>:1(<lambda>)
#         1    0.004    0.004   32.517   32.517 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#     18792    0.006    0.000    0.029    0.000 __init__.py:225(compile)
#     18792    0.014    0.000    0.024    0.000 __init__.py:272(_compile)
#    373491    0.055    0.000    0.055    0.000 __init__.py:33(using_copy_on_write)
#     39933    0.007    0.000    0.007    0.000 __init__.py:43(using_pyarrow_string_dtype)
#         1    0.000    0.000    0.004    0.004 __init__.py:587(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:610(most_common)
#         1    0.000    0.000    0.004    0.004 __init__.py:660(update)
#     44632    0.530    0.000    0.533    0.000 _asarray.py:108(<setcomp>)
#     44632    0.042    0.000    0.598    0.000 _asarray.py:27(require)
#    117448    0.017    0.000    0.017    0.000 _dtype.py:24(_kind_name)
#    117448    0.048    0.000    0.159    0.000 _dtype.py:330(_name_includes_bit_suffix)
#    117448    0.139    0.000    0.339    0.000 _dtype.py:346(_name_get)
#      9396    0.004    0.000    0.004    0.000 _internal.py:920(npy_ctypes_check)
#      2349    0.009    0.000   15.327    0.007 _json.py:1022(_get_object_parser)
#         1    0.000    0.000    0.000    0.000 _json.py:1049(close)
#         1    0.000    0.000    0.000    0.000 _json.py:1059(__iter__)
#      2350    0.429    0.000   15.949    0.007 _json.py:1074(__next__)
#      2349    0.004    0.000    0.004    0.000 _json.py:1126(__init__)
#      2349    0.005    0.000   15.314    0.007 _json.py:1172(parse)
#      2349    0.008    0.000    1.429    0.001 _json.py:1185(_convert_axes)
#     54027    0.176    0.000    6.203    0.000 _json.py:1204(_try_convert_data)
#      7047    0.089    0.000    2.246    0.000 _json.py:1282(_try_convert_to_date)
#      2349    0.042    0.000    3.336    0.001 _json.py:1360(_parse)
#      4698    0.079    0.000   10.476    0.002 _json.py:1396(_process_converter)
#     49329    0.004    0.000    0.004    0.000 _json.py:1401(<lambda>)
#      2349    0.038    0.000   10.545    0.004 _json.py:1422(_try_convert_types)
#     49329    0.016    0.000    4.832    0.000 _json.py:1429(<lambda>)
#      2349    0.030    0.000    3.771    0.002 _json.py:1432(_try_convert_dates)
#     49329    0.039    0.000    0.057    0.000 _json.py:1442(is_ok)
#      2349    0.001    0.000    1.166    0.000 _json.py:1461(<lambda>)
#     49329    0.016    0.000    0.073    0.000 _json.py:1462(<lambda>)
#         1    0.000    0.000    0.001    0.001 _json.py:500(read_json)
#         1    0.000    0.000    0.001    0.001 _json.py:816(__init__)
#         1    0.000    0.000    0.000    0.000 _json.py:896(_preprocess_data)
#         1    0.000    0.000    0.001    0.001 _json.py:912(_get_data_from_filepath)
#      2349    0.025    0.000    0.097    0.000 _json.py:960(_combine_lines)
#    119756    0.020    0.000    0.042    0.000 _json.py:965(<genexpr>)
#      2349    0.013    0.000    0.054    0.000 _json.py:965(<listcomp>)
#      4701    0.002    0.000    0.014    0.000 _methods.py:61(_all)
#      2349    0.003    0.000    0.003    0.000 _mixins.py:270(__getitem__)
#      2349    0.002    0.000    0.051    0.000 _mixins.py:77(method)
#      2349    0.000    0.000    0.000    0.000 _parser.py:1056(_could_be_tzname)
#      2349    0.000    0.000    0.000    0.000 _parser.py:186(__iter__)
#      4698    0.003    0.000    0.014    0.000 _parser.py:189(__next__)
#      2349    0.005    0.000    0.027    0.000 _parser.py:199(split)
#      7047    0.002    0.000    0.003    0.000 _parser.py:203(isword)
#      2349    0.004    0.000    0.008    0.000 _parser.py:221(__init__)
#      2349    0.001    0.000    0.001    0.000 _parser.py:319(jump)
#      2349    0.002    0.000    0.002    0.000 _parser.py:322(weekday)
#      2349    0.001    0.000    0.001    0.000 _parser.py:329(month)
#      2349    0.001    0.000    0.001    0.000 _parser.py:342(ampm)
#      2349    0.003    0.000    0.003    0.000 _parser.py:395(__init__)
#      2349    0.007    0.000    0.007    0.000 _parser.py:62(__init__)
#      2349    0.016    0.000    0.060    0.000 _parser.py:666(_parse)
#      4698    0.008    0.000    0.012    0.000 _parser.py:77(get_token)
#      7047    0.003    0.000    0.019    0.000 _strptime.py:26(_getlang)
#      7047    0.022    0.000    0.045    0.000 _strptime.py:309(_strptime)
#      7047    0.003    0.000    0.049    0.000 _strptime.py:565(_strptime_datetime)
#         1    0.000    0.000    0.000    0.000 _validators.py:450(check_dtype_backend)
#      2349    0.004    0.000   15.979    0.007 algorithms.py:1738(map_array)
#     21141    0.012    0.000    0.038    0.000 api.py:379(default_index)
#      2349    0.002    0.000    0.002    0.000 apply.py:111(__init__)
#      2349    0.004    0.000    0.006    0.000 apply.py:1157(__init__)
#      2349    0.004    0.000   16.156    0.007 apply.py:1189(apply)
#      2349    0.014    0.000   16.146    0.007 apply.py:1262(apply_standard)
#      2349    0.005    0.000    0.018    0.000 array_ops.py:191(_na_arithmetic_op)
#      2349    0.010    0.000    0.043    0.000 array_ops.py:290(comparison_op)
#      2349    0.002    0.000    0.073    0.000 arraylike.py:54(__gt__)
#      2352    0.006    0.000    0.015    0.000 astype.py:139(_astype_float_to_int_nansafe)
#     89262    0.054    0.000    0.730    0.000 astype.py:158(astype_array)
#     82215    0.096    0.000    2.481    0.000 astype.py:192(astype_array_safe)
#     75168    0.186    0.000    0.666    0.000 astype.py:56(_astype_nansafe)
#      9396    0.012    0.000    0.372    0.000 base.py:1037(astype)
#     18792    0.002    0.000    0.002    0.000 base.py:1656(name)
#      2349    0.009    0.000    0.017    0.000 base.py:1682(_validate_names)
#      4698    0.003    0.000    0.004    0.000 base.py:1750(_get_names)
#      2349    0.011    0.000    0.035    0.000 base.py:2292(is_unique)
#   1912086    0.761    0.000    0.884    0.000 base.py:236(construct_from_string)
#    101007    0.059    0.000    0.097    0.000 base.py:3762(get_loc)
#     18792    0.007    0.000    0.029    0.000 base.py:448(size)
#      2349    0.002    0.000    0.003    0.000 base.py:458(_engine_type)
#      9396    0.064    0.000    0.319    0.000 base.py:477(__new__)
#    192618    0.995    0.000    2.684    0.000 base.py:510(find)
#     49329    0.006    0.000    0.014    0.000 base.py:5126(_values)
#      2349    0.003    0.000    0.007    0.000 base.py:5152(_get_engine_target)
#      2349    0.003    0.000    0.003    0.000 base.py:5299(__contains__)
#    202014    0.119    0.000    0.197    0.000 base.py:5349(__getitem__)
#      9396    0.004    0.000    0.004    0.000 base.py:538(<genexpr>)
#      7047    0.005    0.000    0.005    0.000 base.py:573(_ensure_array)
#      7047    0.006    0.000    0.022    0.000 base.py:591(_dtype_to_subclass)
#     65772    0.025    0.000    0.066    0.000 base.py:61(__len__)
#     14094    0.021    0.000    0.033    0.000 base.py:648(_simple_new)
#    101007    0.008    0.000    0.008    0.000 base.py:6611(_maybe_cast_indexer)
#     18792    0.007    0.000    0.036    0.000 base.py:675(empty)
#      7047    0.008    0.000    0.021    0.000 base.py:69(shape)
#      2349    0.010    0.000    0.068    0.000 base.py:7083(_cmp_method)
#     21141    0.004    0.000    0.013    0.000 base.py:71(<genexpr>)
#     35235    0.019    0.000    0.051    0.000 base.py:73(_validate_set_axis)
#     58725    0.022    0.000    0.161    0.000 base.py:7512(ensure_index)
#     37584    0.017    0.000    0.057    0.000 base.py:7607(maybe_extract_name)
#      2349    0.001    0.000    0.006    0.000 base.py:781(_rename)
#      2349    0.001    0.000    0.001    0.000 base.py:790(is_)
#     39933    0.009    0.000    0.009    0.000 base.py:830(_reset_identity)
#      9396    0.015    0.000    0.022    0.000 base.py:836(__iter__)
#      2349    0.011    0.000    0.024    0.000 base.py:841(_engine)
#      2349    0.004    0.000   15.985    0.007 base.py:891(_map_values)
#     51678    0.011    0.000    0.014    0.000 base.py:908(__len__)
#      2349    0.000    0.000    0.000    0.000 base.py:973(dtype)
#     32892    0.005    0.000    0.005    0.000 blocks.py:1003(shape)
#    101007    0.032    0.000    0.044    0.000 blocks.py:1007(iget)
#     65776    0.019    0.000    0.025    0.000 blocks.py:187(is_extension)
#     49330    0.016    0.000    0.034    0.000 blocks.py:192(_can_consolidate)
#     49330    0.040    0.000    0.145    0.000 blocks.py:198(_consolidate_key)
#     54031    0.046    0.000    0.079    0.000 blocks.py:2317(maybe_coerce_values)
#    103361    0.049    0.000    0.065    0.000 blocks.py:2346(get_block_type)
#     14095    0.015    0.000    0.046    0.000 blocks.py:2375(new_block_2d)
#     39936    0.030    0.000    0.057    0.000 blocks.py:2388(new_block)
#     42284    0.004    0.000    0.004    0.000 blocks.py:239(mgr_locs)
#     37587    0.022    0.000    0.030    0.000 blocks.py:2467(extend_blocks)
#     16446    0.013    0.000    0.044    0.000 blocks.py:247(make_block)
#      4698    0.009    0.000    0.017    0.000 blocks.py:2483(ensure_block_shape)
#    169132    0.022    0.000    0.024    0.000 blocks.py:583(dtype)
#     82215    0.053    0.000    2.607    0.000 blocks.py:588(astype)
#     75168    0.060    0.000    0.269    0.000 cast.py:1147(maybe_infer_to_datetimelike)
#      7047    0.011    0.000    0.077    0.000 cast.py:119(maybe_convert_platform)
#     18792    0.013    0.000    0.021    0.000 cast.py:1483(construct_1d_arraylike_from_scalar)
#      7047    0.011    0.000    0.019    0.000 cast.py:1544(construct_1d_object_array_from_listlike)
#      2349    0.001    0.000    0.001    0.000 common.py:1025(needs_i8_conversion)
#      4698    0.005    0.000    0.015    0.000 common.py:1066(is_numeric_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:1107(_maybe_memory_map)
#         1    0.000    0.000    0.000    0.000 common.py:1141(file_exists)
#      2349    0.004    0.000    0.010    0.000 common.py:1148(is_float_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:1155(_is_binary_mode)
#      2349    0.000    0.000    0.001    0.000 common.py:1179(<lambda>)
#      2349    0.002    0.000    0.005    0.000 common.py:1183(is_bool_dtype)
#      7047    0.001    0.000    0.001    0.000 common.py:121(classes)
#         1    0.000    0.000    0.000    0.000 common.py:121(close)
#      7047    0.001    0.000    0.002    0.000 common.py:123(<lambda>)
#    256041    0.040    0.000    0.056    0.000 common.py:1255(is_1d_only_ea_dtype)
#      4698    0.002    0.000    0.002    0.000 common.py:126(_classes_and_not_datetimelike)
#     82215    0.064    0.000    1.378    0.000 common.py:1268(is_extension_array_dtype)
#      4698    0.003    0.000    0.003    0.000 common.py:131(<lambda>)
#     14094    0.005    0.000    0.008    0.000 common.py:1322(is_ea_or_datetimelike_dtype)
#      4698    0.003    0.000    0.008    0.000 common.py:1366(_is_dtype)
#      4698    0.004    0.000    0.009    0.000 common.py:137(is_object_dtype)
#      7047    0.001    0.000    0.002    0.000 common.py:1390(_get_dtype)
#     11745    0.007    0.000    0.014    0.000 common.py:1425(_is_dtype_type)
#         2    0.000    0.000    0.000    0.000 common.py:145(is_url)
#    202014    0.046    0.000    0.062    0.000 common.py:149(cast_scalar_indexer)
#     25839    0.012    0.000    0.039    0.000 common.py:1562(validate_all_hashable)
#     51678    0.010    0.000    0.018    0.000 common.py:1581(<genexpr>)
#    129195    0.290    0.000    2.085    0.000 common.py:1587(pandas_dtype)
#         5    0.000    0.000    0.000    0.000 common.py:173(_expand_user)
#         4    0.000    0.000    0.000    0.000 common.py:233(stringify_path)
#         2    0.000    0.000    0.000    0.000 common.py:277(is_fsspec_url)
#         1    0.000    0.000    0.000    0.000 common.py:289(_get_filepath_or_buffer)
#    117450    0.053    0.000    0.150    0.000 common.py:296(maybe_iterable_to_list)
#      2349    0.001    0.000    0.001    0.000 common.py:367(apply_if_callable)
#         1    0.000    0.000    0.000    0.000 common.py:503(get_compression_method)
#      4698    0.002    0.000    0.002    0.000 common.py:514(is_string_or_object_np_dtype)
#      2349    0.001    0.000    0.006    0.000 common.py:521(is_string_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:538(infer_compression)
#     54027    0.014    0.000    0.042    0.000 common.py:556(require_length_match)
#      2349    0.002    0.000    0.003    0.000 common.py:557(condition)
#      2349    0.004    0.000    0.082    0.000 common.py:62(new_method)
#         1    0.000    0.000    0.001    0.001 common.py:652(get_handle)
#      2349    0.003    0.000    0.003    0.000 common.py:977(is_numeric_v_string_like)
#     30537    0.038    0.000    0.086    0.000 config.py:127(_get_single_key)
#     30537    0.022    0.000    0.132    0.000 config.py:145(_get_option)
#     30537    0.012    0.000    0.145    0.000 config.py:271(__call__)
#     30537    0.007    0.000    0.007    0.000 config.py:615(_select_options)
#     30537    0.020    0.000    0.025    0.000 config.py:633(_get_root)
#     61074    0.019    0.000    0.019    0.000 config.py:647(_get_deprecated_option)
#     30537    0.008    0.000    0.015    0.000 config.py:674(_translate_key)
#     30537    0.010    0.000    0.022    0.000 config.py:686(_warn_if_deprecated)
#      2349    0.002    0.000    0.342    0.000 construction.py:1006(convert_object_array)
#     49329    0.033    0.000    0.331    0.000 construction.py:1028(convert)
#      2349    0.009    0.000    0.340    0.000 construction.py:1068(<listcomp>)
#      7047    0.003    0.000    0.003    0.000 construction.py:196(mgr_to_mgr)
#    103356    0.031    0.000    0.039    0.000 construction.py:419(extract_array)
#      4698    0.016    0.000    2.441    0.001 construction.py:423(dict_to_mgr)
#      4698    0.021    0.000    0.147    0.000 construction.py:481(<listcomp>)
#     63427    0.024    0.000    0.027    0.000 construction.py:484(ensure_wrapped_if_datetimelike)
#      4698    0.059    0.000    0.351    0.000 construction.py:487(<listcomp>)
#      2349    0.007    0.000    0.691    0.000 construction.py:506(nested_data_to_arrays)
#     79866    0.190    0.000    0.623    0.000 construction.py:518(sanitize_array)
#      2349    0.002    0.000    0.005    0.000 construction.py:532(treat_as_nested)
#      7047    0.141    0.000    0.773    0.000 construction.py:596(_homogenize)
#      7047    0.002    0.000    0.003    0.000 construction.py:675(_sanitize_non_ordered)
#     61074    0.025    0.000    0.045    0.000 construction.py:683(_sanitize_ndim)
#     58725    0.015    0.000    0.019    0.000 construction.py:722(_sanitize_str_dtypes)
#     61074    0.012    0.000    0.015    0.000 construction.py:742(_maybe_repeat)
#      2349    0.007    0.000    0.674    0.000 construction.py:793(to_arrays)
#      2349    0.012    0.000    0.304    0.000 construction.py:891(_list_of_dict_to_arrays)
#    119756    0.040    0.000    0.046    0.000 construction.py:915(<genexpr>)
#      4698    0.001    0.000    0.001    0.000 construction.py:916(<genexpr>)
#      2349    0.010    0.000    0.010    0.000 construction.py:922(<listcomp>)
#      2349    0.015    0.000    0.360    0.000 construction.py:928(_finalize_columns_and_data)
#      2349    0.002    0.000    0.003    0.000 construction.py:950(_validate_or_indexify_columns)
#      7047    0.032    0.000    2.579    0.000 construction.py:96(arrays_to_mgr)
#    117407    0.041    0.000   15.842    0.000 core.py:282(emoji_list)
#    117407    2.904    0.000   15.801    0.000 core.py:289(<listcomp>)
#      2349    0.002    0.000    0.004    0.000 dataclasses.py:1256(is_dataclass)
#      9396    0.001    0.000    0.001    0.000 datetimelike.py:1991(freq)
#      2349    0.001    0.000    0.001    0.000 datetimelike.py:2060(_creso)
#      4698    0.002    0.000    0.006    0.000 datetimelike.py:2064(unit)
#      2349    0.002    0.000    0.006    0.000 datetimelike.py:2267(copy)
#      2349    0.004    0.000    0.012    0.000 datetimelike.py:2316(ensure_arraylike_for_datetimelike)
#      2349    0.000    0.000    0.000    0.000 datetimelike.py:2388(validate_inferred_freq)
#      2349    0.002    0.000    0.003    0.000 datetimelike.py:2425(maybe_infer_freq)
#      4698    0.002    0.000    0.003    0.000 datetimelike.py:2453(dtype_to_unit)
#      2349    0.001    0.000    0.002    0.000 datetimelike.py:316(asi8)
#      2349    0.006    0.000    0.012    0.000 datetimelike.py:368(__getitem__)
#      2349    0.002    0.000    0.002    0.000 datetimelike.py:385(_get_getitem_freq)
#     18792    0.005    0.000    0.024    0.000 datetimes.py:156(should_cache)
#      2349    0.013    0.000    0.054    0.000 datetimes.py:2159(_sequence_to_dt64ns)
#     18792    0.026    0.000    0.890    0.000 datetimes.py:216(_maybe_cache)
#      2349    0.004    0.000    0.020    0.000 datetimes.py:2378(maybe_convert_dtype)
#      2349    0.000    0.000    0.000    0.000 datetimes.py:2464(_validate_dt64_dtype)
#      4698    0.001    0.000    0.001    0.000 datetimes.py:2520(_validate_tz_from_dtype)
#      7047    0.014    0.000    0.023    0.000 datetimes.py:274(_simple_new)
#      2349    0.003    0.000    0.026    0.000 datetimes.py:279(tz_convert)
#      2349    0.004    0.000    0.059    0.000 datetimes.py:284(tz_localize)
#      2349    0.014    0.000    0.082    0.000 datetimes.py:299(_from_sequence_not_strict)
#      2349    0.008    0.000    0.103    0.000 datetimes.py:318(__new__)
#     18792    0.027    0.000    0.577    0.000 datetimes.py:369(_convert_listlike_datetimes)
#     18792    0.038    0.000    0.530    0.000 datetimes.py:526(_to_datetime_with_unit)
#     37584    0.005    0.000    0.005    0.000 datetimes.py:539(dtype)
#      4698    0.002    0.000    0.004    0.000 datetimes.py:564(tz)
#     18792    0.052    0.000    1.675    0.000 datetimes.py:721(to_datetime)
#      2349    0.005    0.000    0.020    0.000 datetimes.py:825(tz_convert)
#      7047    0.005    0.000    0.013    0.000 datetimes.py:88(tz_to_dtype)
#      2349    0.013    0.000    0.049    0.000 datetimes.py:901(tz_localize)
#      2349    0.001    0.000    0.003    0.000 dispatch.py:17(should_extension_dispatch)
#    173826    0.121    0.000    0.164    0.000 dtypes.py:1021(construct_from_string)
#      9396    0.004    0.000    0.014    0.000 dtypes.py:122(__repr__)
#    173826    0.119    0.000    0.152    0.000 dtypes.py:1266(construct_from_string)
#    173826    0.080    0.000    0.104    0.000 dtypes.py:1789(construct_from_string)
#    173826    0.078    0.000    0.101    0.000 dtypes.py:2180(construct_from_string)
#    173826    0.063    0.000    0.070    0.000 dtypes.py:332(construct_from_string)
#      4698    0.005    0.000    0.008    0.000 dtypes.py:734(__init__)
#      4698    0.002    0.000    0.004    0.000 dtypes.py:766(_creso)
#     30537    0.003    0.000    0.003    0.000 dtypes.py:773(unit)
#     25839    0.003    0.000    0.003    0.000 dtypes.py:787(tz)
#    173826    0.097    0.000    0.132    0.000 dtypes.py:814(construct_from_string)
#     23490    0.016    0.000    0.021    0.000 dtypes.py:850(__str__)
#     14094    0.004    0.000    0.015    0.000 dtypes.py:853(name)
#     28188    0.012    0.000    0.024    0.000 dtypes.py:863(__eq__)
#     18792    0.002    0.000    0.002    0.000 enum.py:1249(value)
#     18792    0.007    0.000    0.009    0.000 enum.py:193(__get__)
#      2349    0.002    0.000    0.010    0.000 expressions.py:226(evaluate)
#      2349    0.001    0.000    0.009    0.000 expressions.py:67(_evaluate_standard)
#    147990    0.047    0.000    0.047    0.000 flags.py:53(__init__)
#    119802    0.012    0.000    0.012    0.000 flags.py:57(allows_duplicate_labels)
#    119802    0.028    0.000    0.028    0.000 flags.py:89(allows_duplicate_labels)
#    103356    0.049    0.000    1.804    0.000 frame.py:1392(items)
#      4698    0.001    0.000    0.003    0.000 frame.py:1539(__len__)
#    101007    0.113    0.000    1.483    0.000 frame.py:3776(_ixs)
#      2349    0.010    0.000    0.071    0.000 frame.py:3853(__getitem__)
#    101007    0.100    0.000    0.834    0.000 frame.py:4384(_box_col_values)
#     11745    0.004    0.000    0.005    0.000 frame.py:4399(_clear_item_cache)
#    101007    0.135    0.000    1.764    0.000 frame.py:4402(_get_item_cache)
#    101007    0.031    0.000    0.240    0.000 frame.py:651(_sliced_from_mgr)
#    101007    0.057    0.000    0.381    0.000 frame.py:654(_constructor_sliced_from_mgr)
#      7047    0.038    0.000    4.094    0.001 frame.py:665(__init__)
#     14095    0.001    0.000    0.001    0.000 fromnumeric.py:1021(_argsort_dispatcher)
#     14095    0.008    0.000    0.029    0.000 fromnumeric.py:1025(argsort)
#     14095    0.007    0.000    0.021    0.000 fromnumeric.py:53(_wrapfunc)
#      2349    0.002    0.000    0.002    0.000 frozen.py:73(__getitem__)
#    147990    0.164    0.000    0.211    0.000 generic.py:274(__init__)
#    117453    0.058    0.000    0.238    0.000 generic.py:335(_from_mgr)
#    119802    0.012    0.000    0.012    0.000 generic.py:358(attrs)
#    526176    0.088    0.000    0.119    0.000 generic.py:37(_check)
#    239604    0.028    0.000    0.028    0.000 generic.py:393(flags)
#    526176    0.133    0.000    0.271    0.000 generic.py:42(_instancecheck)
#     18792    0.008    0.000    0.127    0.000 generic.py:487(_validate_dtype)
#      4698    0.002    0.000    0.002    0.000 generic.py:548(_get_axis_number)
#      4698    0.005    0.000    0.006    0.000 generic.py:562(_get_axis)
#    119802    0.198    0.000    0.288    0.000 generic.py:6147(__finalize__)
#     23490    0.014    0.000    0.014    0.000 generic.py:6189(__getattr__)
#    455709    0.250    0.000    0.416    0.000 generic.py:6206(__setattr__)
#     82215    0.090    0.000    4.557    0.000 generic.py:6368(astype)
#     35235    0.034    0.000    0.151    0.000 generic.py:760(_set_axis)
#         1    0.000    0.000    0.000    0.000 heapq.py:523(nlargest)
#         1    0.000    0.000    0.000    0.000 heapq.py:565(<listcomp>)
#         1    0.000    0.000    0.000    0.000 heapq.py:579(<listcomp>)
#      2349    0.002    0.000    0.002    0.000 indexing.py:2678(check_dict_or_set_indexers)
#         3    0.000    0.000    0.000    0.000 inference.py:105(is_file_like)
#    103356    0.061    0.000    0.149    0.000 inference.py:273(is_dict_like)
#    288927    0.045    0.000    0.062    0.000 inference.py:300(<genexpr>)
#      2349    0.001    0.000    0.002    0.000 inference.py:306(is_named_tuple)
#    176175    0.038    0.000    0.051    0.000 inference.py:334(is_hashable)
#      2349    0.004    0.000    0.007    0.000 inference.py:404(is_dataclass)
#     82215    0.016    0.000    0.021    0.000 inspect.py:292(isclass)
#      7047    0.005    0.000    0.007    0.000 locale.py:396(normalize)
#      7047    0.003    0.000    0.010    0.000 locale.py:479(_parse_localename)
#      7047    0.004    0.000    0.016    0.000 locale.py:593(getlocale)
#    101007    0.014    0.000    0.014    0.000 managers.py:169(blknos)
#      7047    0.005    0.000    0.094    0.000 managers.py:1726(is_consolidated)
#      7047    0.011    0.000    0.090    0.000 managers.py:1734(_consolidate_check)
#      7047    0.040    0.000    0.077    0.000 managers.py:1740(<listcomp>)
#      7047    0.011    0.000    0.677    0.000 managers.py:1744(_consolidate_inplace)
#    140943    0.023    0.000    0.023    0.000 managers.py:1799(__init__)
#     16446    0.013    0.000    0.018    0.000 managers.py:1812(from_blocks)
#     23490    0.040    0.000    0.123    0.000 managers.py:1825(from_array)
#    101007    0.014    0.000    0.014    0.000 managers.py:185(blklocs)
#    140943    0.016    0.000    0.016    0.000 managers.py:1902(_block)
#    305373    0.231    0.000    0.262    0.000 managers.py:1949(dtype)
#    136242    0.029    0.000    0.032    0.000 managers.py:1960(internal_values)
#      7047    0.016    0.000    1.765    0.000 managers.py:2068(create_block_manager_from_column_arrays)
#    147987    0.040    0.000    0.070    0.000 managers.py:2124(_grouping_func)
#      7047    0.171    0.000    1.071    0.000 managers.py:2137(_form_blocks)
#      4698    0.009    0.000    0.032    0.000 managers.py:2174(<listcomp>)
#     44632    0.107    0.000    0.137    0.000 managers.py:2194(_stack_arrays)
#      7047    0.032    0.000    0.521    0.000 managers.py:2207(_consolidate)
#     98660    0.019    0.000    0.164    0.000 managers.py:2212(<lambda>)
#     21141    0.111    0.000    0.296    0.000 managers.py:2224(_merge_blocks)
#     14095    0.013    0.000    0.017    0.000 managers.py:2233(<listcomp>)
#     14095    0.004    0.000    0.004    0.000 managers.py:2242(<listcomp>)
#     35235    0.018    0.000    0.069    0.000 managers.py:225(set_axis)
#     70470    0.010    0.000    0.010    0.000 managers.py:235(items)
#     82215    0.107    0.000    2.768    0.000 managers.py:308(apply)
#     82215    0.009    0.000    0.009    0.000 managers.py:335(<dictcomp>)
#     82215    0.071    0.000    2.861    0.000 managers.py:405(astype)
#      7047    0.001    0.000    0.001    0.000 managers.py:896(__init__)
#    101007    0.207    0.000    0.303    0.000 managers.py:991(iget)
#      4698    0.002    0.000    0.023    0.000 missing.py:101(isna)
#      2349    0.002    0.000    0.002    0.000 missing.py:131(dispatch_fill_zeros)
#      4698    0.006    0.000    0.021    0.000 missing.py:184(_isna)
#      2349    0.008    0.000    0.009    0.000 missing.py:261(_isna_array)
#     18792    0.009    0.000    0.010    0.000 missing.py:642(na_value_for_dtype)
#    133893    0.011    0.000    0.011    0.000 multiarray.py:1080(copyto)
#     28190    0.003    0.000    0.003    0.000 multiarray.py:153(concatenate)
#    133893    0.108    0.000    0.167    0.000 numeric.py:274(full)
#    328856    0.076    0.000    0.107    0.000 numerictypes.py:283(issubclass_)
#    164428    0.095    0.000    0.212    0.000 numerictypes.py:357(issubdtype)
#         2    0.000    0.000    0.000    0.000 parse.py:108(_noop)
#         2    0.000    0.000    0.000    0.000 parse.py:119(_coerce_args)
#         2    0.000    0.000    0.000    0.000 parse.py:374(urlparse)
#      2349    0.003    0.000    0.071    0.000 range.py:1030(_cmp_method)
#      2349    0.004    0.000    0.011    0.000 range.py:134(__new__)
#     25839    0.022    0.000    0.032    0.000 range.py:198(_simple_new)
#      2349    0.000    0.000    0.000    0.000 range.py:213(_validate_dtype)
#      2349    0.004    0.000    0.008    0.000 range.py:234(_data)
#      2349    0.001    0.000    0.001    0.000 range.py:281(start)
#      2349    0.000    0.000    0.000    0.000 range.py:299(stop)
#      2349    0.000    0.000    0.000    0.000 range.py:316(step)
#     21141    0.002    0.000    0.002    0.000 range.py:377(dtype)
#      2349    0.002    0.000    0.005    0.000 range.py:484(_view)
#      2349    0.004    0.000    0.029    0.000 range.py:489(copy)
#    256041    0.048    0.000    0.065    0.000 range.py:963(__len__)
#         1    0.000    0.000    0.000    0.000 readers.py:518(validate_integer)
#    101007    0.052    0.000    0.132    0.000 series.py:1372(_set_as_cached)
#     23490    0.002    0.000    0.002    0.000 series.py:1381(_clear_item_cache)
#     23490    0.158    0.000    1.037    0.000 series.py:371(__init__)
#      2349    0.005    0.000   16.167    0.007 series.py:4625(apply)
#     21144    0.003    0.000    0.003    0.000 series.py:577(_constructor)
#     16446    0.014    0.000    0.059    0.000 series.py:581(_constructor_from_mgr)
#    305373    0.072    0.000    0.334    0.000 series.py:626(dtype)
#     25839    0.019    0.000    0.033    0.000 series.py:653(name)
#     23490    0.017    0.000    0.052    0.000 series.py:703(name)
#    136242    0.031    0.000    0.064    0.000 series.py:750(_values)
#     98658    0.025    0.000    0.031    0.000 series.py:784(_references)
#     65772    0.014    0.000    0.096    0.000 series.py:821(__len__)
#     14095    0.004    0.000    0.006    0.000 shape_base.py:207(_arrays_for_stack_dispatcher)
#     14095    0.005    0.000    0.011    0.000 shape_base.py:215(_vhstack_dispatcher)
#     14095    0.043    0.000    0.073    0.000 shape_base.py:219(vstack)
#     14095    0.001    0.000    0.001    0.000 shape_base.py:77(_atleast_2d_dispatcher)
#     14095    0.021    0.000    0.027    0.000 shape_base.py:81(atleast_2d)
#    173826    0.066    0.000    0.071    0.000 string_.py:135(construct_from_string)
#  17140706    8.506    0.000   12.145    0.000 tokenizer.py:158(tokenize)
#     42922    0.009    0.000    0.009    0.000 tokenizer.py:29(__init__)
#    117407    0.010    0.000    0.010    0.000 tokenizer.py:301(get_search_tree)
#    199665    0.012    0.000    0.012    0.000 typing.py:2256(cast)
#     18792    0.032    0.000    0.087    0.000 warnings.py:130(filterwarnings)
#    110403    0.051    0.000    0.179    0.000 warnings.py:165(simplefilter)
#    129195    0.090    0.000    0.146    0.000 warnings.py:181(_add_filter)
#    129195    0.036    0.000    0.036    0.000 warnings.py:440(__init__)
#    129195    0.088    0.000    0.095    0.000 warnings.py:466(__enter__)
#    129195    0.059    0.000    0.066    0.000 warnings.py:487(__exit__)
#  17180690    1.185    0.000    1.185    0.000 {built-in method __new__ of type object at 0x105effd60}
#    263098    0.033    0.000    0.033    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup_error}
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup}
#     49773    0.031    0.000    0.031    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.004    0.004    0.004    0.004 {built-in method _collections._count_elements}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heapify}
#         8    0.000    0.000    0.000    0.000 {built-in method _heapq.heapreplace}
#      7047    0.002    0.000    0.002    0.000 {built-in method _locale.setlocale}
#      2349    0.008    0.000    0.008    0.000 {built-in method _operator.gt}
#      7047    0.002    0.000    0.002    0.000 {built-in method _simple_new}
#    387585    0.020    0.000    0.020    0.000 {built-in method _warnings._filters_mutated}
#    133893    0.037    0.000    0.110    0.000 {built-in method builtins.all}
#      2349    0.001    0.000    0.002    0.000 {built-in method builtins.any}
#     84564    0.006    0.000    0.006    0.000 {built-in method builtins.callable}
#         1    0.000    0.000   32.517   32.517 {built-in method builtins.exec}
#    930210    0.066    0.000    0.066    0.000 {built-in method builtins.getattr}
#    249005    0.024    0.000    0.024    0.000 {built-in method builtins.hasattr}
#    178524    0.013    0.000    0.013    0.000 {built-in method builtins.hash}
# 27659650/27349582    1.375    0.000    1.698    0.000 {built-in method builtins.isinstance}
#    911414    0.068    0.000    0.068    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 1435208/995945    0.161    0.000    0.269    0.000 {built-in method builtins.len}
#     32886    0.005    0.000    0.031    0.000 {built-in method builtins.setattr}
#      7047    0.012    0.000    0.170    0.000 {built-in method builtins.sorted}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#      2349    0.003    0.000    0.003    0.000 {built-in method numpy.arange}
#     44632    0.022    0.000    0.022    0.000 {built-in method numpy.array}
#     42284    0.003    0.000    0.003    0.000 {built-in method numpy.asanyarray}
#    152685    0.026    0.000    0.026    0.000 {built-in method numpy.asarray}
#      4698    0.002    0.000    0.002    0.000 {built-in method numpy.datetime_data}
#    204364    0.063    0.000    0.063    0.000 {built-in method numpy.empty}
#      2349    1.695    0.001    1.695    0.001 {built-in method pandas._libs.json.ujson_loads}
#      2349    0.002    0.000    0.002    0.000 {built-in method pandas._libs.missing.checknull}
#      4698    0.001    0.000    0.001    0.000 {built-in method pandas._libs.tslibs.dtypes.abbrev_to_npy_unit}
#      4698    0.001    0.000    0.001    0.000 {built-in method pandas._libs.tslibs.dtypes.is_supported_unit}
#      2349    0.001    0.000    0.001    0.000 {built-in method pandas._libs.tslibs.offsets.to_offset}
#      2349    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.is_utc}
#      9396    0.003    0.000    0.003    0.000 {built-in method pandas._libs.tslibs.timezones.maybe_get_tz}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#      2349    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x117c48e00}
#      2349    0.003    0.000    0.003    0.000 {function TimelikeOps.copy at 0x1163389a0}
#      7047    0.001    0.000    0.001    0.000 {method '__exit__' of '_thread.lock' objects}
#      2349    0.001    0.000    0.001    0.000 {method '_from_backing_data' of 'pandas._libs.arrays.NDArrayBacked' objects}
#      7047    0.029    0.000    0.050    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#     14094    0.005    0.000    0.005    0.000 {method 'add_index_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#      4701    0.003    0.000    0.017    0.000 {method 'all' of 'numpy.ndarray' objects}
#  17443783    0.603    0.000    0.603    0.000 {method 'append' of 'list' objects}
#     14095    0.012    0.000    0.012    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#     93957    0.095    0.000    0.095    0.000 {method 'astype' of 'numpy.ndarray' objects}
#     11745    0.001    0.000    0.001    0.000 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#     14094    0.007    0.000    0.007    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    223164    0.023    0.000    0.023    0.000 {method 'endswith' of 'str' objects}
#      7047    0.007    0.000    0.020    0.000 {method 'extend' of 'list' objects}
#     89260    0.017    0.000    0.017    0.000 {method 'format' of 'str' objects}
#    160372    0.013    0.000    0.013    0.000 {method 'get' of 'dict' objects}
#    101007    0.030    0.000    0.030    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#    129195    0.013    0.000    0.013    0.000 {method 'insert' of 'list' objects}
#      7047    0.001    0.000    0.001    0.000 {method 'isalpha' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#      2349    0.017    0.000    0.017    0.000 {method 'join' of 'str' objects}
#    122105    0.006    0.000    0.006    0.000 {method 'keys' of 'dict' objects}
#    239607    0.017    0.000    0.017    0.000 {method 'lower' of 'str' objects}
#    180875    0.031    0.000    0.031    0.000 {method 'match' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#      9396    0.001    0.000    0.001    0.000 {method 'read' of '_io.StringIO' objects}
#      4701    0.012    0.000    0.012    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    129195    0.036    0.000    0.036    0.000 {method 'remove' of 'list' objects}
#      4698    0.006    0.000    0.006    0.000 {method 'reshape' of 'pandas._libs.arrays.NDArrayBacked' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#    173826    0.014    0.000    0.014    0.000 {method 'search' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#     30537    0.005    0.000    0.005    0.000 {method 'split' of 'str' objects}
#    404033    0.046    0.000    0.046    0.000 {method 'startswith' of 'str' objects}
#    117407    0.022    0.000    0.022    0.000 {method 'strip' of 'str' objects}
#     44632    0.003    0.000    0.003    0.000 {method 'upper' of 'str' objects}
#      4698    0.002    0.000    0.002    0.000 {method 'view' of 'numpy.ndarray' objects}
#      2349    0.072    0.000    0.072    0.000 {pandas._libs.lib.dicts_to_array}
#      2349    0.042    0.000    0.088    0.000 {pandas._libs.lib.fast_unique_multiple_list_gen}
#      2349    0.002    0.000    0.002    0.000 {pandas._libs.lib.is_all_arraylike}
#    202015    0.016    0.000    0.016    0.000 {pandas._libs.lib.is_float}
#    204364    0.017    0.000    0.017    0.000 {pandas._libs.lib.is_integer}
#     11745    0.001    0.000    0.001    0.000 {pandas._libs.lib.is_iterator}
#    136242    0.030    0.000    0.030    0.000 {pandas._libs.lib.is_list_like}
#    267784    0.027    0.000    0.027    0.000 {pandas._libs.lib.is_np_dtype}
#     21141    0.003    0.000    0.003    0.000 {pandas._libs.lib.is_scalar}
#      7047    0.001    0.000    0.001    0.000 {pandas._libs.lib.item_from_zerodim}
#      2349    0.045    0.000   15.969    0.007 {pandas._libs.lib.map_infer}
#    131544    0.267    0.000    0.429    0.000 {pandas._libs.lib.maybe_convert_objects}
#     18792    0.179    0.000    0.288    0.000 {pandas._libs.tslib.array_with_unit_to_datetime}
#      2349    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.np_datetime.is_unitless}
#     11745    0.002    0.000    0.002    0.000 {pandas._libs.tslibs.np_datetime.py_get_unit_from_dtype}
#      4698    0.003    0.000    0.003    0.000 {pandas._libs.tslibs.timezones.tz_standardize}
#      2349    0.006    0.000    0.006    0.000 {pandas._libs.tslibs.tzconversion.tz_localize_to_utc}

# %% [markdown]
# ## Consumo de memoria de q2_memory

# %% [markdown]
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     70    101.9 MiB    101.9 MiB           1   @profile
#     71                                         def q2_memory(file_path: str) -> List[Tuple[str, int]]:
#     72                                             # Este código es el mismo que q2_time.py con la diferencia que leemos los datos en particiones
#     73                                             # para ahorrar memoria.
#     74                                             # Para realizar esto, utilizamos el parámetro chunksize.
#     75                                             # Por lo tanto, es necesario hacer un bucle "for" y sacrificar procesamiento.
#     76
#     77    101.9 MiB      0.0 MiB           1       emoji_lists = []
#     78    123.8 MiB     20.5 MiB        2350       for chunk in pd.read_json(path_or_buf=file_path, lines=True, chunksize=50):
#     79    123.8 MiB      1.4 MiB        2349           emojis = chunk['content'].apply(extract_emojis)
#     80    123.8 MiB      0.0 MiB        2349           emoji_lists.extend(emojis) #extend nos permite concatenar listas y almacenar los resultados de cada partición
#     81
#     82                                             # La lista "emojis_list" tiene listas como elementos (es una lista de listas).
#     83                                             # Con este bucle concatenamos todas las listas en una sola.
#     84    123.8 MiB      0.0 MiB           1       all_emojis = []
#     85    123.8 MiB      0.0 MiB      117408       for i in emoji_lists:
#     86    123.8 MiB      0.0 MiB      117407           all_emojis += i
#     87
#     88                                             # Retornamos la salida de get_most_common_elements.
#     89    123.8 MiB      0.0 MiB           1       return get_most_common_elements(all_emojis)

# %% [markdown]
# ## Conclusiones:
#
# - En la función q2_time leemos los datos usando la librería jsonlines que permite una lectura rápida y además, no es necesario leer todas las "keys" que trae cada JSON. Por lo tanto, tampoco consume mucha memoria.
# - En la función q2_memory leemos los datos utilizando el método de pandas pd.read_json(), el cual nos permite leer los datos en particiones utilizando el parámetro chuncksize. Se pierde mucha velocidad ya que hay que repetir todo el código para cada partición, pero se ahorra un poco de memoria.
# - Si bien en este ejemplo el ahorro de memoria no es significativo, a gran escala, la columna "content" podría tener millones de millones de datos y entonces el enfoque de q2_memory comenzaría a tomar una gran importancia en el ahorro de memoria.
